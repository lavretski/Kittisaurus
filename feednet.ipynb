# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.7.0

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='sigmoid'),
  tf.keras.layers.Dense(10, activation='sigmoid')
])

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[0.45531154, 0.42136213, 0.84341145, 0.31395215, 0.39905983,
#         0.5869856 , 0.60197484, 0.7224765 , 0.46894026, 0.31065482]],
#       dtype=float32)

# %%
loss_cross_entropy = tf.keras.losses.SparseCategoricalCrossentropy()
opt = tf.keras.optimizers.SGD(learning_rate=0.3)

# %%
model.compile(optimizer = 'SGD',
              loss = loss_cross_entropy,
              metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 968us/step - loss: 0.3798 - accuracy: 0.8965
# Epoch 2/5
# 1875/1875 [==============================] - 2s 955us/step - loss: 0.3604 - accuracy: 0.9003
# Epoch 3/5
# 1875/1875 [==============================] - 2s 967us/step - loss: 0.3456 - accuracy: 0.90290s - loss: 0.3437 - accura
# Epoch 4/5
# 1875/1875 [==============================] - 2s 986us/step - loss: 0.3339 - accuracy: 0.9058
# Epoch 5/5
# 1875/1875 [==============================] - 2s 929us/step - loss: 0.3241 - accuracy: 0.9083

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.3060 - accuracy: 0.9131 - 180ms/epoch - 575us/step
# [0.3059690296649933, 0.913100004196167]
