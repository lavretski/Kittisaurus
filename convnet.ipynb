# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
batch_size = 10

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(20, (5, 5), activation = 'relu', input_shape = (28, 28, 1)),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
  tf.keras.layers.Conv2D(64, (5, 5), activation = 'relu', input_shape = (28, 28, 1)),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(100, activation='relu'), 
  tf.keras.layers.Dense(10, activation='sigmoid')
])
#model.build((None, batch_size))

# %%
model.summary()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_52 (Conv2D)          (None, 24, 24, 20)        520
#
#  max_pooling2d_47 (MaxPoolin  (None, 12, 12, 20)       0
#  g2D)
#
#  conv2d_53 (Conv2D)          (None, 8, 8, 64)          32064
#
#  max_pooling2d_48 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  flatten_17 (Flatten)        (None, 1024)              0
#
#  dense_35 (Dense)            (None, 100)               102500
#
#  dense_36 (Dense)            (None, 10)                1010
#
# ...
# Total params: 136,094
# Trainable params: 136,094
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = model(x_train[:10]).numpy()
predictions
# Out:
# array([[0.49739432, 0.5585803 , 0.4978628 , 0.523293  , 0.5747044 ,
#         0.5212796 , 0.5360635 , 0.5587146 , 0.5338711 , 0.5077286 ],
#        [0.49596092, 0.55655354, 0.49111608, 0.5243736 , 0.5439263 ,
#         0.53510934, 0.53661054, 0.5593645 , 0.5265218 , 0.4923091 ],
#        [0.4971012 , 0.52917325, 0.4958014 , 0.5351472 , 0.5426434 ,
#         0.5059401 , 0.5300326 , 0.52470464, 0.5335616 , 0.49745545],
#        [0.48855683, 0.54820865, 0.4838883 , 0.48314464, 0.5781327 ,
#         0.5027342 , 0.5260794 , 0.53576314, 0.5112336 , 0.49339473],
#        [0.50034285, 0.55518514, 0.5021827 , 0.5298287 , 0.5680269 ,
#         0.52052355, 0.52258927, 0.55232644, 0.5363424 , 0.48290378],
#        [0.5096979 , 0.55376464, 0.47654593, 0.5204323 , 0.555717  ,
#         0.5139978 , 0.5140849 , 0.53104836, 0.51878226, 0.48324233],
#        [0.4892192 , 0.5224674 , 0.50513256, 0.50395817, 0.5789846 ,
#         0.5022082 , 0.52417266, 0.5529798 , 0.5332499 , 0.4969851 ],
# ...

# %%
loss_cross_entropy = tf.keras.losses.SparseCategoricalCrossentropy()
opt = tf.keras.optimizers.SGD(learning_rate=0.1)

# %%
model.compile(optimizer = 'SGD',
              loss = loss_cross_entropy,
              metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs=20, batch_size = batch_size)
# Out:
# Epoch 1/20
# 6000/6000 [==============================] - 34s 6ms/step - loss: 0.2362 - accuracy: 0.9278
# Epoch 2/20
# 6000/6000 [==============================] - 34s 6ms/step - loss: 0.0714 - accuracy: 0.9777
# Epoch 3/20
# 6000/6000 [==============================] - 34s 6ms/step - loss: 0.0496 - accuracy: 0.9846
# Epoch 4/20
# 6000/6000 [==============================] - 34s 6ms/step - loss: 0.0387 - accuracy: 0.9883
# Epoch 5/20
# 6000/6000 [==============================] - 34s 6ms/step - loss: 0.0322 - accuracy: 0.9897
# Epoch 6/20
# 6000/6000 [==============================] - 34s 6ms/step - loss: 0.0270 - accuracy: 0.9912
# Epoch 7/20
# 6000/6000 [==============================] - 35s 6ms/step - loss: 0.0226 - accuracy: 0.9930
# Epoch 8/20
# 6000/6000 [==============================] - 35s 6ms/step - loss: 0.0194 - accuracy: 0.9934
# Epoch 9/20
# 6000/6000 [==============================] - 35s 6ms/step - loss: 0.0175 - accuracy: 0.9947
# Epoch 10/20
# ...

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.0279 - accuracy: 0.9919 - 926ms/epoch - 3ms/step
# [0.027872543781995773, 0.9919000267982483]

# %%
model.save('mnist_conv_relu_sigmoid.h5')

# %%
model = tf.keras.models.load_model('mnist_conv_relu_sigmoid.h5')

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.0279 - accuracy: 0.9919 - 816ms/epoch - 3ms/step
# [0.027872543781995773, 0.9919000267982483]
